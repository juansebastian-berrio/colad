# %% [markdown]
# <a href="https://colab.research.google.com/github/juansebastian-berrio/colad/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Esta sesión detalla el entrenamiento de modelos de aprendizaje automático para el reconocimiento de patrones utilizando el conjunto de datos MNIST. La explicación comienza con un clasificador binario enfocado en un solo dígito para evidenciar las limitaciones de la precisión global frente a clases desbalanceadas, justificando así el uso de la matriz de confusión y la curva ROC. Finalmente, el contenido avanza hacia la clasificación multiclase para procesar todos los dígitos simultáneamente, concluyendo con los criterios técnicos esenciales para el diseño del sistema.
