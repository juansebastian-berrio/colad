# %% [markdown]
# <a href="https://colab.research.google.com/github/juansebastian-berrio/colad/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# El mapa de ruta de la ciencia de datos muestra por dónde empezar y cuáles son los conocimientos necesarios para desarrollarse en este campo.
#
# La ciencia de datos se apoya en varios componentes fundamentales. El motor lógico y sus fundamentos están relacionados principalmente con la estadística, que permite analizar e interpretar los datos.
#
# Los fundamentos matemáticos incluyen conocimientos de matemáticas, especialmente álgebra, que sirven como base para comprender conceptos más avanzados.
#
# Después se encuentra la capa inteligente, que incluye la ruta inteligente, compuesta por áreas como Machine Learning (aprendizaje automático) y Text Mining / NLP (procesamiento del lenguaje natural).
#
# También son importantes la infraestructura y la visualización de datos, ya que permiten trabajar con grandes cantidades de información y presentar los resultados de manera clara.
#
# El Data Munging se relaciona con la preparación y limpieza de los datos para que puedan ser utilizados correctamente en los análisis y modelos.
#
# Finalmente, el toolbox (caja de herramientas) reúne las diferentes herramientas y tecnologías que se utilizan durante el proceso de ciencia de datos.
#
# En conjunto, esta ruta representa un viaje hacia el futuro de la ciencia de datos, en el que se adquieren conocimientos y herramientas para analizar información, construir modelos y transformar los sistemas mediante los datos.
