# %% [markdown]
# <a href="https://colab.research.google.com/github/juansebastian-berrio/colad/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Predictive Modeling for House Prices
#
# This notebook aims to demonstrate how to build predictive models for house prices using Linear Regression and Decision Trees, comparing their performance. We will use the 'iowa-housing-prices' dataset from Kaggle.

# %% [markdown]
# ### Step 1: Set up Kaggle API and Download Data
#
# To download the dataset directly from Kaggle, you'll need to set up your Kaggle API credentials. Follow these steps:
#
# 1.  **Create an API Token**: Go to your Kaggle account page (https://www.kaggle.com/settings) and click 'Create New API Token'. This will download a `kaggle.json` file.
# 2.  **Upload `kaggle.json` to Colab**: In the Colab environment, click on the folder icon on the left sidebar to open the 'Files' section. Then, click the 'Upload' icon and upload your `kaggle.json` file.
# 3.  **Run the following cells** to install the Kaggle library and set up permissions.

# %%
# Install the Kaggle library to interact with Kaggle API
# This allows us to download datasets directly from Kaggle into our Colab environment.
# !pip install kaggle

# %%
# Renombrar el archivo 'kaggle (1).json' a 'kaggle.json'
# Esto es necesario porque el script espera 'kaggle.json' sin el '(1)'.
# !mv '/content/kaggle (1).json' '/content/kaggle.json'
print('Archivo renombrado de kaggle (1).json a kaggle.json')
# Out:
# mv: cannot stat '/content/kaggle (1).json': No such file or directory
# Archivo renombrado de kaggle (1).json a kaggle.json

# %%
# Create a .kaggle directory if it doesn't exist
# This directory is where Kaggle expects to find the API token.
# !mkdir -p ~/.kaggle

# Move the uploaded kaggle.json file to the .kaggle directory
# The mv command moves the file from the current directory to the hidden .kaggle directory.
# !mv kaggle.json ~/.kaggle/

# Set read-write permissions for the kaggle.json file
# This is crucial for security, as the API token should only be readable by the owner.
# !chmod 600 ~/.kaggle/kaggle.json

# %% [markdown]
# ### Step 2: Download the Dataset
#
# Now that the Kaggle API is configured, we can download the dataset. The reference notebook uses the 'iowa-housing-prices' dataset from the 'alexisbcook/exercise-introduction' kernel, which corresponds to the `alexisbcook/iowa-housing-prices` dataset slug on Kaggle.

# %%
# Download the Iowa Housing Prices dataset from Kaggle
# The 'kaggle datasets download' command retrieves the specified dataset.
# The '-d' flag is used to specify the dataset slug.
# !kaggle datasets download -d alexisbcook/iowa-housing-prices
# Out:
# 403 Client Error: Forbidden for url: https://api.kaggle.com/v1/datasets.DatasetApiService/GetDatasetMetadata

# %%
# Unzip the downloaded dataset file
# Kaggle datasets are often downloaded as zip files, so we need to extract their contents.
# The 'unzip' command extracts all files from 'iowa-housing-prices.zip'.
# !unzip iowa-housing-prices.zip
# Out:
# unzip:  cannot find or open iowa-housing-prices.zip, iowa-housing-prices.zip.zip or iowa-housing-prices.zip.ZIP.

# %% [markdown]
# ### Step 3: Load the Data
#
# We'll use the pandas library to load the CSV data into a DataFrame, which is a tabular data structure that is easy to work with in Python.

# %% [markdown]
# ### Intentando con un Dataset Diferente: Titanic
#
# Como el dataset anterior tuvo problemas de acceso, probaremos con el clásico dataset de "Titanic - Machine Learning from Disaster". Este es un buen dataset para prácticas y debería funcionar sin problemas.

# %%
# Descargar el dataset del Titanic desde Kaggle
# Usamos el slug del dataset 'titanic' de Kaggle.
# El comando 'kaggle datasets download' descarga el conjunto de datos especificado.
# La bandera '-d' se utiliza para especificar el 'slug' del dataset.
# !kaggle datasets download -d titanic
# Out:
# 403 Client Error: Forbidden for url: https://api.kaggle.com/v1/datasets.DatasetApiService/GetDatasetMetadata

# %%
# Descomprimir el archivo ZIP descargado del dataset del Titanic
# Los datasets de Kaggle a menudo se descargan como archivos zip.
# El comando 'unzip' extrae todos los archivos del 'titanic.zip'.
# !unzip titanic.zip
# Out:
# unzip:  cannot find or open titanic.zip, titanic.zip.zip or titanic.zip.ZIP.

# %%
# Importar la librería pandas, esencial para la manipulación y análisis de datos
# La abreviamos como 'pd' por comodidad, una convención común.
import pandas as pd

# Leer el archivo CSV de datos de entrenamiento del Titanic en un DataFrame de pandas
# 'train.csv' es uno de los archivos extraídos del archivo zip del Titanic.
# El resultado se almacena en una variable llamada 'titanic_data'.
titanic_data = pd.read_csv('train.csv')

# Mostrar las primeras 5 filas del DataFrame
# Esto nos da una visión rápida de los datos, incluyendo nombres de columnas y algunos valores de muestra.
display(titanic_data.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1796/3050780056.py in <cell line: 0>()
#       6 # 'train.csv' es uno de los archivos extraídos del archivo zip del Titanic.
#       7 # El resultado se almacena en una variable llamada 'titanic_data'.
# ----> 8 titanic_data = pd.read_csv('train.csv')
#       9
#      10 # Mostrar las primeras 5 filas del DataFrame
#
# ...

# %%
# Import the pandas library, which is essential for data manipulation and analysis
# We alias it as 'pd' for convenience, a common convention.
import pandas as pd

# Read the training data CSV file into a pandas DataFrame
# 'train.csv' is one of the files extracted from the zip archive.
# The result is stored in a variable called 'home_data'.
home_data = pd.read_csv('train.csv')

# Display the first 5 rows of the DataFrame
# This gives a quick overview of the data, including column names and some sample values.
display(home_data.head())
