# %% [markdown]
# <a href="https://colab.research.google.com/github/juansebastian-berrio/colad/blob/main/Untitled13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# TensorFlow es una herramienta fundamental para desarrollar modelos de inteligencia artificial, ya que trabaja con tensores como materia prima de los cálculos. A través de variables, funciones y grafos de computación, permite construir y personalizar modelos con Keras. Uno de sus procesos principales es el cálculo de gradientes, realizado mediante la autodiferenciación en modo inverso, donde se utilizan los gradientes y la regla de la cadena para determinar cómo ajustar los parámetros del modelo. Además, TensorFlow permite crear bucles de entrenamiento personalizados, siguiendo pasos como ingresar una muestra, realizar el paso hacia adelante, calcular los gradientes y aplicar la optimización. Finalmente, AutoGraph facilita convertir ciertas estructuras de Python en grafos de computación, haciendo más eficiente la ejecución de los modelos.
